# %%
import requests, json
import pandas as pd

url = "https://www.sofascore.com/api/v1/event/12436451/lineups"

response = requests.request("GET", url)

jsondata = json.loads(response.text)
# Out:
# /Users/sbarrae/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
player_data = pd.DataFrame(jsondata['home']['players'])

# %%
player_data
# Out:
#                                                player  teamId  shirtNumber  \
# 0   {'name': 'Ederson', 'slug': 'ederson', 'shortN...      17           31
# 1   {'name': 'Kyle Walker', 'firstName': '', 'last...      17            2
# 2   {'name': 'Rúben Dias', 'firstName': '', 'lastN...      17            3
# 3   {'name': 'Joško Gvardiol', 'slug': 'josko-gvar...      17           24
# 4   {'name': 'Matheus Nunes', 'firstName': '', 'la...      17           27
# 5   {'name': 'İlkay Gündoğan', 'slug': 'ilkay-gund...      17           19
# 6   {'name': 'Bernardo Silva', 'slug': 'bernardo-s...      17           20
# 7   {'name': 'Kevin De Bruyne', 'slug': 'kevin-de-...      17           17
# 8   {'name': 'Phil Foden', 'firstName': '', 'lastN...      17           47
# 9   {'name': 'Jérémy Doku', 'slug': 'jeremy-doku',...      17           11
# 10  {'name': 'Erling Haaland', 'slug': 'erling-haa...      17            9
# 11  {'name': 'Mateo Kovačić', 'slug': 'mateo-kovac...      17            8
# 12  {'name': 'Jack Grealish', 'firstName': '', 'la...      17           10
# 13  {'name': 'Savinho', 'slug': 'savio', 'shortNam...      17           26
# 14  {'name': 'Stefan Ortega', 'slug': 'stefan-orte...      17           18
# 15  {'name': 'John Stones', 'slug': 'john-stones',...      17            5
# 16  {'name': 'Jahmai Simpson-Pusey', 'firstName': ...   36544           66
# 17  {'name': 'Nico O'Reilly', 'firstName': 'Nico',...   36544           75
# 18  {'name': 'James McAtee', 'slug': 'james-mcatee...      17           87
# 19  {'name': 'Divin Mubama', 'firstName': '', 'las...   36544           67
#
#    jerseyNumber position  substitute  \
# 0            31        G       False
# 1             2        D       False
# 2             3        D       False
# 3            24        D       False
# 4            27        D       False
# 5            19        M       False
# 6            20        M       False
# 7            17        M       False
# 8            47        M       False
# 9            11        M       False
# 10            9        F       False
# 11            8        M        True
# 12           10        M        True
# 13           26        F        True
# 14           18        G        True
# 15            5        D        True
# 16           66        D        True
# 17           75        M        True
# 18           87        M        True
# 19           67        M        True
#
#                                            statistics captain
# 0   {'totalPass': 35, 'accuratePass': 28, 'totalLo...     NaN
# 1   {'totalPass': 72, 'accuratePass': 55, 'totalLo...    True
# 2   {'totalPass': 51, 'accuratePass': 50, 'totalLo...     NaN
# 3   {'totalPass': 47, 'accuratePass': 42, 'totalLo...     NaN
# 4   {'totalPass': 58, 'accuratePass': 50, 'totalLo...     NaN
# 5   {'totalPass': 62, 'accuratePass': 60, 'totalLo...     NaN
# 6   {'totalPass': 14, 'accuratePass': 12, 'totalLo...     NaN
# 7   {'totalPass': 30, 'accuratePass': 25, 'goalAss...     NaN
# 8   {'totalPass': 52, 'accuratePass': 48, 'totalLo...     NaN
# 9   {'totalPass': 28, 'accuratePass': 22, 'goalAss...     NaN
# 10  {'totalPass': 12, 'accuratePass': 6, 'goalAssi...     NaN
# 11  {'totalPass': 27, 'accuratePass': 25, 'goalAss...     NaN
# 12  {'totalPass': 6, 'accuratePass': 5, 'goalAssis...     NaN
# 13  {'totalPass': 4, 'accuratePass': 4, 'goalAssis...     NaN
# 14                                                 {}     NaN
# 15                                                 {}     NaN
# 16                                                 {}     NaN
# 17                                                 {}     NaN
# 18                                                 {}     NaN
# 19                                                 {}     NaN
